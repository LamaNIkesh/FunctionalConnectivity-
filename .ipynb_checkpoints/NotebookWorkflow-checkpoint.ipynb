# %%
import connectivityClass as cn

# %%
#instance of the class
M = cn.MatrixGenerate()

# %%
#File location for the isi_distance calculated. This will be used to generate the graph
SynchronyFileLocation = 'isi_distance.npy'

# %%
#generatePandasDF method spits out a panda dataframe with three columns: Ch_A(cahnnel A), Ch_B(channel B), and SyncValue(synchonry between the two) 
links = M.generatePandasDF(SynchronyFileLocation)
print(links.count)
# Out:
# [[0, 5, 0.6800989787478267], [0, 6, 0.8031066190633204], [0, 7, 0.8683404313690999], [0, 8, 0.656778800244141], [0, 10, 0.600538388101003], [0, 11, 0.4143362455726092], [0, 12, 0.4897198259740098], [0, 14, 0.5732842214087763], [0, 15, 0.8228610661712772], [0, 16, 0.7995206109922094], [0, 17, 0.8299221650368388], [0, 18, 0.8554490513771136], [0, 19, 0.8705772863566217], [0, 20, 0.8140504817520583], [0, 21, 0.696232658747187], [0, 22, 0.8343289602951016], [0, 23, 0.8120993357196608], [0, 24, 0.667956585899346], [0, 25, 0.5076557062631766], [0, 27, 0.6128917302117399], [0, 28, 0.5908819989534275], [0, 29, 0.4071807831837929], [0, 30, 0.7612382007837745], [0, 31, 0.7808737963305996], [0, 34, 0.43933528298463914], [0, 35, 0.623589040162238], [0, 36, 0.4783470312970809], [0, 37, 0.41061586793167787], [0, 38, 0.5471955533698563], [0, 40, 0.53540532419961], [0, 43, 0.5793000635183924], [0, 45, 0.6292324856807031], [0, 48, 0.8814544137728227], [0, 49, 0.7800678393964351], [0, 51, 0.5175332967
# ...

# %%
M.GenerateGraphFromPandas(links)
